# %% [markdown]
# # First print your name in the cell below then save this file. (or something nice about your instructor)

# %%
# In this cell print your name 
print('Georgios is very cool!')
# Out:
# Georgios is very cool!

# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
df = pd.read_csv('data/listings.csv')
print(df)
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
# ...

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100?

priceLow = df['price'] < 100
len(df[priceLow])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # 1. How many listings are there with a price less than 100?
# ----> 3 priceLow = df['price'] < 100
#       4 len(df[priceLow])
#
# NameError: name 'df' is not defined

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.

listingsBrooklyn = df['neighbourhood_group'] == 'Brooklyn'
df_bk = df[listingsBrooklyn]
len(df_bk)
# Out:
# 18632

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

listingBrooklyn = (df['neighbourhood_group'] == 'Brooklyn') & (df['price'] < 100)
len(df[listingBrooklyn])
# Out:
# 10473

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
# How many total are there that have those names

hosts = ['David', 'John', 'Michael', 'Daniel']
names = df['host_name'].isin(hosts)
len(df[names])
# Out:
# 1258

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before. 

# Condition to filter Williamsburg listings
select_condition = df['neighbourhood'] == 'Williamsburg'
df['adjusted_price'] = df['price'] 

# Use .loc accessor, specify rows and cols
df.loc[select_condition, 'adjusted_price'] = df['price'] + 100

# Sanity check
df[select_condition]
# Out:
#              id                                               name    host_id  \
# 11         6848                   Only 2 stops to Manhattan studio      15991
# 15         7801                   Sweet and Spacious Brooklyn Loft      21207
# 35        14290                         * ORIGINAL BROOKLYN LOFT *      56104
# 38        14377                   Williamsburg 1 bedroom Apartment      56512
# 42        15385                              Very, very cozy place      60252
# ...         ...                                                ...        ...
# 46484  44746041      Modern, light-filled apartment in Wiliamsburg    3317380
# 46489  44749327  Luxury 3 bedroom apartment Williamsburg ROOF P...  334780877
# 46493  44753863            Bright, spacious East Williamsburg loft   38062951
# 46513  44800276        Williamsburg 1 Bedroom, Spacious and Classy  361034257
# 46517  44802032                  A very large room in Williamsburg  213793805
#
# ...

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  

typeRoom = ['Private room', 'Shared room']
dfPercent = df.room_type.value_counts(normalize=True)[typeRoom] * 100
dfPercent
# Out:
# room_type
# Private room    45.444581
# Shared room      2.121349
# Name: proportion, dtype: float64

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.

groupListings = df.groupby('neighbourhood_group')
groupListings['neighbourhood_group'].count()
# Out:
# neighbourhood_group
# Bronx             1183
# Brooklyn         18632
# Manhattan        20580
# Queens            5791
# Staten Island      341
# Name: neighbourhood_group, dtype: int64

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 

groupListings = df.groupby('neighbourhood_group')
groupListings['price'].mean()
# Out:
# neighbourhood_group
# Bronx             92.751479
# Brooklyn         120.225258
# Manhattan        191.880466
# Queens            99.754965
# Staten Island    110.947214
# Name: price, dtype: float64

# %%
# 2.5. Using `groupby`, find the mean price for each room_type. 

groupListings = df.groupby('room_type')
groupListings['price'].mean()
# Out:
# room_type
# Entire home/apt    199.395950
# Hotel room         275.015075
# Private room        91.453084
# Shared room         87.063830
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 

groupListings = df.groupby('neighbourhood_group')
groupListings['price'].agg(['min', 'max'])
# Out:
#                      min    max
# neighbourhood_group
# Bronx                 16   1404
# Brooklyn               0  10000
# Manhattan              0  10000
# Queens                 0  10000
# Staten Island         19   1200

# %%
# 4. Using `groupby`, find the mean price for each room_type in each neighbourhood_group.
grouping = ['neighbourhood_group', 'room_type']
groupListings = df.groupby(grouping)
groupListings['price'].mean()
# Out:
# neighbourhood_group  room_type
# Bronx                Entire home/apt    138.004819
#                      Private room        68.419668
#                      Shared room         66.391304
# Brooklyn             Entire home/apt    171.587687
#                      Hotel room         147.300000
#                      Private room        71.291189
#                      Shared room         57.870091
# Manhattan            Entire home/apt    231.335572
#                      Hotel room         292.515670
#                      Private room       128.277069
#                      Shared room        111.735084
# Queens               Entire home/apt    150.168900
#                      Hotel room         139.058824
#                      Private room        69.972564
#                      Shared room         89.891892
# Staten Island        Entire home/apt    151.720930
#                      Private room        70.312883
#                      Shared room         46.000000
# ...

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.

grouping = ['neighbourhood_group', 'room_type']
groupListings = df.groupby(grouping)
groupListings['price'].agg(['count', 'min', 'max', 'mean', 'median', 'std'])
# Out:
#                                      count  min    max        mean  median  \
# neighbourhood_group room_type
# Bronx               Entire home/apt    415   25   1404  138.004819   103.0
#                     Private room       722   16    700   68.419668    55.0
#                     Shared room         46   20    800   66.391304    44.0
# Brooklyn            Entire home/apt   9112   20  10000  171.587687   135.0
#                     Hotel room          30    0    399  147.300000   129.0
#                     Private room      9159   10   2500   71.291189    60.0
#                     Shared room        331   15   1500   57.870091    36.0
# Manhattan           Entire home/apt  12209    0  10000  231.335572   165.0
#                     Hotel room         351    0   2211  292.515670   210.0
#                     Private room      7601   10  10000  128.277069    80.0
#                     Shared room        419   10  10000  111.735084    60.0
# ...

# %% [markdown]
# # Load, Merge, and Export files.
# 1. Load the `prices.csv` and the `n_listings.csv`
#     * Having an error..? Inspect the actual csv file if you're having trouble
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv` into the data folder.
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`
dp = pd.read_csv('data/prices.csv')
dv = pd.read_csv('data/n_listings.csv', sep=';')

# %%
# 2. Do join that keeps all the records for each table.
new_df = pd.merge(dp, 
                  dv, 
                  on='neighbourhood_group', 
                  how='outer')
new_df
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx    92.751479      1183.0
# 1            Brooklyn   120.225258     18632.0
# 2          LongIsland          NaN      4121.0
# 3           Manhattan   191.880466     20580.0
# 4              Queens    99.754965         NaN
# 5       Staten Island   110.947214         NaN

# %%
# 3. Save your joined csv as `joined.csv` into the data folder. 

new_df.to_csv('data/joined.csv', index=False)

# %%
# 4. Load your newly saved file, see if it looks the same.  If not, try saving with argument `index=False`
dff = pd.read_csv('data/joined.csv')
dff
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx    92.751479      1183.0
# 1            Brooklyn   120.225258     18632.0
# 2          LongIsland          NaN      4121.0
# 3           Manhattan   191.880466     20580.0
# 4              Queens    99.754965         NaN
# 5       Staten Island   110.947214         NaN

# %% [markdown]
# # Extra Credit
# Every question below this cell is extra credit and optional.

# %% [markdown]
# ### 1. (Easy) Explore this new PandasAI Package and tell me what its all about because I've never used it.
# * https://www.youtube.com/watch?v=5w6eZaoDVVk&ab_channel=CodingIsFun
# * See if you can use it on the listings.csv to find out some cool info. or answer some of the questions above.
#
# PandasAI is a Python library that serves to make Pandas more interactive. By installing it and simply creating a PandasAI object, you can ask questions about your dataframe and it will provide the answers without any code necessary.
#
# You can ask PandasAI to give you the top highest or lowest values in a dataframe based on a specific condition, calculate values, or even generate a histogram based on the data!
#
# To install it, run 'pip install pandasai' in the terminal. Then, import PandasAI and OpenAI from the pandasai package. In order to use OpenAI, you will need an API key which you can generate in the OpenAI website.
#
# (Note: At the time this video was made, the OpenAi API key is not free-- but it is affordable)

# %% [markdown]
# ### 2. (Very Easy) Find other cool Panda packages / add ons and show us what they can do well. And how you installed them.

# %% [markdown]
# ### 3. (Medium) Use the grammys.csv data for the next section of questions.
#
# 1. Who won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
extra_df = pd.read_csv('data/grammys.csv')

# Answer to question 1
conditionOne = (extra_df['year'] == 2016) & (extra_df['winner'] == True) & (extra_df['category'] == "Album of the Year")
winnersOne = extra_df[conditionOne]
winnersOne
# Out:
#       year           category nominee  \
# 5505  2016  Album of the Year   1989.
#
#                                                 workers  winner
# 5505  Taylor Swift (artist/producer), Jack Antonoff ...    True

# %%
# Answer to question 2
conditionTwo = (extra_df['year'] == 2009) & (extra_df['winner'] == True) & (extra_df['category'] == "Best Rap Album")
winnersTwo = extra_df[conditionTwo]
winnersTwo
# Out:
#       year        category         nominee     workers  winner
# 4396  2009  Best Rap Album  Tha Carter III  Lil' Wayne    True

# %%
# Answer to question 3
conditionThree = (extra_df['workers'] == "Kendrick Lamar") & (extra_df['winner'] == True)
winnersThree = extra_df[conditionThree]
winnersThree
len(extra_df[conditionThree])
# Out:
# 4

# %% [markdown]
# ### (Hard) Load the Game Logs for 2022 and add the column names using a dictionary.
# * [Link to the data page](https://www.retrosheet.org/gamelogs/)
# * [Link to the column names](https://procatinator.com/)
# * haha, gotta find them yourself!

# %%
game_df = pd.read_csv('data/gamelogs.csv', header=None)

columnDictionary = { 0: 'Date', 1: 'Number', 2: 'Day_of_Week', 3: 'Visiting_Team', 4: 'Visiting_League', 5: 'Visiting_Team_Game_Number', 6: 'Home_Team',
    7: 'Home_League', 8: 'Home_Team_Game_Number', 9: 'Visiting_Score', 10: 'Home_Score', 11: 'Length_of_Game', 12: 'Day_Night_Indicator', 13: 'Completion',
    14: 'Forfeit', 15: 'Protest', 16: 'Park_ID', 17: 'Attendance', 18: 'Time_of_Game_in_Minutes', 19: 'Visiting_Line_Scores', 20: 'Home_Line_Scores', 21: 'V_At-Bats',
    22: 'V_Hits', 23: 'V_Doubles', 24: 'V_Triples', 25: 'V_Homeruns', 26: 'V_RBI', 27: 'V_Sacrifice_Hits', 28: 'V_Sacrifice_Flies', 29: 'V_Hit-By-Pitch', 30: 'V_Walks',
    31: 'V_Intentional_Walks', 32: 'V_Strikeouts', 33: 'V_Stolen_Bases', 34: 'V_Caught_Stealing', 35: 'V_Grounded_Into_Double_Plays', 36: 'V_Awarded_First_On_Catcher_Interference',
    37: 'V_Left_on_Base', 38: 'V_Pitchers_Used', 39: 'V_Individual_Earned_Runs', 40: 'V_Team_Earned_Runs', 41: 'V_Wild_Pitches', 42: 'V_Balks', 43: 'V_Putouts',
    44: 'V_Assists', 45: 'V_Errors', 46: 'V_Passed_Balls', 47: 'V_Double_Plays', 48: 'V_Triple_Plays', 49: 'H_At-Bats', 50: 'H_Hits', 51: 'H_Doubles', 52: 'H_Triples',
    53: 'H_Homeruns', 54: 'H_RBI', 55: 'H_Sacrifice_Hits', 56: 'H_Sacrifice_Flies', 57: 'H_Hit-By-Pitch', 58: 'H_Walks', 59: 'H_Intentional_Walks', 60: 'H_Strikeouts',
    61: 'H_Stolen_Bases', 62: 'H_Caught_Stealing', 63: 'H_Grounded_Into_Double_Plays', 64: 'H_Awarded_First_On_Catcher_Interference', 65: 'H_Left_on_Base', 66: 'H_Pitchers_Used',
    67: 'H_Individual_Earned_Runs', 68: 'H_Team_Earned_Runs', 69: 'H_Wild_Pitches', 70: 'H_Balks', 71: 'H_Putouts', 72:'H_Assists', 73: 'H_Errors', 74: 'H_Passed_Balls',
    75: 'H_Double_Plays', 76: 'H_Triple_Plays', 77: 'H_Plate_Umpire_ID', 78: 'H_Plate_Umpire_Name', 79: '1B_Umpire_ID', 80: '1B_Umpire_Name', 81: ''
}

game_df = game_df.rename(columns=columnDictionary)

game_df
# Out:
#           Date  Number Day_of_Week Visiting_Team Visiting_League  \
# 0     20220407       0         Thu           SDN              NL
# 1     20220407       0         Thu           CIN              NL
# 2     20220407       0         Thu           MIL              NL
# 3     20220407       0         Thu           PIT              NL
# 4     20220407       0         Thu           NYN              NL
# ...        ...     ...         ...           ...             ...
# 2425  20221005       0         Wed           KCA              AL
# 2426  20221005       0         Wed           PHI              NL
# 2427  20221005       0         Wed           ANA              AL
# 2428  20221005       0         Wed           DET              AL
# 2429  20221005       0         Wed           NYA              AL
#
#       Visiting_Team_Game_Number Home_Team Home_League  Home_Team_Game_Number  \
# 0                             1       ARI          NL                      1
# ...

# %% [markdown]
# ### (Extra Hard) Download the files for the past 5 years into a new folder and add them all into one data frame using pandas, then save that new file.
# * Try to not hard code in the file names. We want to do this programmatically because what if we want to add new/more file names in the future.
